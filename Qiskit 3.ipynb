# %% [markdown]
# Installing Libraries

# %%
# !pip install qiskit
# !pip install pylatexenc
# !pip install qiskit qiskit-aer
# Out:
# Requirement already satisfied: qiskit in /usr/local/lib/python3.10/dist-packages (0.44.1)
# Requirement already satisfied: qiskit-terra==0.25.1 in /usr/local/lib/python3.10/dist-packages (from qiskit) (0.25.1)
# Requirement already satisfied: rustworkx>=0.13.0 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra==0.25.1->qiskit) (0.13.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra==0.25.1->qiskit) (1.23.5)
# Requirement already satisfied: ply>=3.10 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra==0.25.1->qiskit) (3.11)
# Requirement already satisfied: psutil>=5 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra==0.25.1->qiskit) (5.9.5)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra==0.25.1->qiskit) (1.10.1)
# Requirement already satisfied: sympy>=1.3 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra==0.25.1->qiskit) (1.12)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra==0.25.1->qiskit) (0.3.7)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra==0.25.1->qiskit) (2.8.2)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra==0.25.1->qiskit) (5.1.0)
# Requirement already satisfied: symengine<0.10,>=0.9 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra==0.25.1->qiskit) (0.9.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from qiskit-terra==0.25.1->qiskit) (4.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.0->qiskit-terra==0.25.1->qiskit) (1.16.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from stevedore>=3.0.0->qiskit-terra==0.25.1->qiskit) (5.11.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy>=1.3->qiskit-terra==0.25.1->qiskit) (1.3.0)
# Requirement already satisfied: pylatexenc in /usr/local/lib/python3.10/dist-packages (2.10)
# Requirement already satisfied: qiskit in /usr/local/lib/python3.10/dist-packages (0.44.1)
# Requirement already satisfied: qiskit-aer in /usr/local/lib/python3.10/dist-packages (0.12.2)
# Requirement already satisfied: qiskit-terra==0.25.1 in /usr/local/lib/python3.10/dist-packages (from qiskit) (0.25.1)
# Requirement already satisfied: rustworkx>=0.13.0 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra==0.25.1->qiskit) (0.13.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra==0.25.1->qiskit) (1.23.5)
# Requirement already satisfied: ply>=3.10 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra==0.25.1->qiskit) (3.11)
# Requirement already satisfied: psutil>=5 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra==0.25.1->qiskit) (5.9.5)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra==0.25.1->qiskit) (1.10.1)
# Requirement already satisfied: sympy>=1.3 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra==0.25.1->qiskit) (1.12)
# Requirement already satisfied: dill>=0.3 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra==0.25.1->qiskit) (0.3.7)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra==0.25.1->qiskit) (2.8.2)
# Requirement already satisfied: stevedore>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra==0.25.1->qiskit) (5.1.0)
# Requirement already satisfied: symengine<0.10,>=0.9 in /usr/local/lib/python3.10/dist-packages (from qiskit-terra==0.25.1->qiskit) (0.9.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from qiskit-terra==0.25.1->qiskit) (4.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.0->qiskit-terra==0.25.1->qiskit) (1.16.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from stevedore>=3.0.0->qiskit-terra==0.25.1->qiskit) (5.11.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy>=1.3->qiskit-terra==0.25.1->qiskit) (1.3.0)

# %% [markdown]
# # Importing Libraries

# %%
from qiskit import *
from qiskit.tools.monitor import job_monitor
from qiskit.tools.visualization import plot_state_qsphere
from qiskit.visualization import plot_histogram, plot_bloch_multivector, array_to_latex

# %% [markdown]
# # Single Quantum Gate
# # Only single qbit is needed to implement

# %% [markdown]
# # X gate/ Not gate
# X gate -> flips state |0> to |1> and vice versa

# %%
# create a circuit
circuit = QuantumCircuit(1)

# set initial state
initial_state = [0,1]

#Inital state initialize
circuit.initialize(initial_state, 0)

# apply gate
circuit.x(0)

# draw circuit
circuit.draw(output ='mpl', initial_state =True)

# %%
 # select simulator
simulator = Aer.get_backend('aer_simulator')

# save statevector
circuit.save_statevector()

#assemble circuit
qobj = assemble(circuit)

job = simulator.run(qobj)

# monitor job
job_monitor(job)

# get result
result = job.result()

# get statevector
final_state = result.get_statevector()
# Out:
# <ipython-input-48-b98e121f13c0>:10: DeprecationWarning: Using a qobj for run() is deprecated as of qiskit-aer 0.9.0 and will be removed no sooner than 3 months from that release date. Transpiled circuits should now be passed directly using `backend.run(circuits, **run_options).
#   job = simulator.run(qobj)
# Job Status: job has successfully run

# %%
print(final_state)
array_to_latex(final_state)
# Out:
# Statevector([1.+0.j, 0.+0.j],
#             dims=(2,))
# $$
#
# \begin{bmatrix}
# 1 & 0  \\
#  \end{bmatrix}
# $$

# %%
plot_bloch_multivector(final_state)

# %% [markdown]
# # Matrix representation of X gate

# %%
# create a circuit
circuit = QuantumCircuit(1,1)

# set initial state
# initial_state = [0,1]

#Inital state initialize
# circuit.initialize(initial_state, 0)

# apply gate
circuit.x(0)

# apply measurement
circuit.measure(0,0)

# draw circuit
circuit.draw(output ='mpl', initial_state =True)

# %%
 # select simulator
simulator = Aer.get_backend('aer_simulator')

# save unitary
circuit.save_statevector()

#assemble circuit
qobj = assemble(circuit)

job = simulator.run(qobj)

# monitor job
job_monitor(job)

# get result
result = job.result()

# get statevector
final_state = result.get_statevector()
# Out:
# <ipython-input-52-667cdfce5d41>:10: DeprecationWarning: Using a qobj for run() is deprecated as of qiskit-aer 0.9.0 and will be removed no sooner than 3 months from that release date. Transpiled circuits should now be passed directly using `backend.run(circuits, **run_options).
#   job = simulator.run(qobj)
# Job Status: job has successfully run

# %%
print(final_state)
array_to_latex(final_state)
# Out:
# Statevector([0.+0.j, 1.+0.j],
#             dims=(2,))
# $$
#
# \begin{bmatrix}
# 0 & 1  \\
#  \end{bmatrix}
# $$

# %%
print(unitary)
array_to_latex(unitary)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-06b5e42d454c> in <cell line: 1>()
# ----> 1 print(unitary)
#       2 array_to_latex(unitary)
#
# NameError: name 'unitary' is not defined

# %% [markdown]
# # Identity Gate

# %%
# Create Circuit

circuit = QuantumCircuit(1)

# apply gate
circuit.id(0)

# draw circuit
circuit.draw(output = 'mpl', initial_state = True)

# %%
 # select simulator
simulator = Aer.get_backend('aer_simulator')

# save statevector
circuit.save_statevector()

#assemble circuit
qobj = assemble(circuit)

job = simulator.run(qobj)

# monitor job
job_monitor(job)

# get result
result = job.result()

# get statevector
final_state = result.get_statevector()

# %%
print(final_state)
array_to_latex(final_state)

# %% [markdown]
# # Identity gate does not perform any operation, state remains same as before. Identity gate is a absence of a gate.

# %%
plot_bloch_multivector(final_state)

# %% [markdown]
# # 2 qbit gate

# %%
# create circuit
circuit = QuantumCircuit(2)

#apply gate
# circuit.cx(control qbit, target qbit)
circuit.cx(1,0)

# circuit draw
circuit.draw(output='mpl', initial_state=True)

# %%
 # select simulator
simulator = Aer.get_backend('aer_simulator')

# save statevector
circuit.save_statevector()

#assemble circuit
qobj = assemble(circuit)

job = simulator.run(qobj)

# monitor job
job_monitor(job)

# get result
result = job.result()

# get statevector
final_state = result.get_statevector()

# %%
print(final_state)
array_to_latex(final_state)

# %%
plot_bloch_multivector(final_state)

# %%
plot_state_qsphere(final_state)

# %% [markdown]
# # Swap gate

# %%
# Create circuit
circuit = QuantumCircuit(2)

# apply x gate
circuit.x(0)

# apply gate
circuit.swap(0,1)

#circuit draw
circuit.draw(output = 'mpl', initial_state =True)

# %%
 # select simulator
simulator = Aer.get_backend('aer_simulator')

# save statevector
circuit.save_statevector()

#assemble circuit
qobj = assemble(circuit)

job = simulator.run(qobj)

# monitor job
job_monitor(job)

# get result
result = job.result()

# get statevector
final_state = result.get_statevector()
# Out:
# <ipython-input-57-b98e121f13c0>:10: DeprecationWarning: Using a qobj for run() is deprecated as of qiskit-aer 0.9.0 and will be removed no sooner than 3 months from that release date. Transpiled circuits should now be passed directly using `backend.run(circuits, **run_options).
#   job = simulator.run(qobj)
# Job Status: job has successfully run

# %%
print(final_state)
array_to_latex(final_state)
# Out:
# Statevector([0.+0.j, 0.+0.j, 1.+0.j, 0.+0.j],
#             dims=(2, 2))
# $$
#
# \begin{bmatrix}
# 0 & 0 & 1 & 0  \\
#  \end{bmatrix}
# $$

# %% [markdown]
# statevector [0 0 1 0]
# q state [00 01 10 11]

# %%
plot_bloch_multivector(final_state)

# %%
plot_state_qsphere(final_state)

# %% [markdown]
# # 3 QbitGate

# %%
# create circuit

circuit = QuantumCircuit(3)

# apply x gate
circuit.x(0)
circuit.x(1)

#apply gate
circuit.ccx(0,1,2)

# draw circuit
circuit.draw(output = 'mpl', initial_state = True)

# %%
  # select simulator
simulator = Aer.get_backend('aer_simulator')

# save statevector
circuit.save_statevector()

#assemble circuit
qobj = assemble(circuit)

job = simulator.run(qobj)

# monitor job
job_monitor(job)

# get result
result = job.result()

# get statevector
final_state = result.get_statevector()
# Out:
# <ipython-input-67-b98e121f13c0>:10: DeprecationWarning: Using a qobj for run() is deprecated as of qiskit-aer 0.9.0 and will be removed no sooner than 3 months from that release date. Transpiled circuits should now be passed directly using `backend.run(circuits, **run_options).
#   job = simulator.run(qobj)
# Job Status: job has successfully run

# %%
print(final_state)
array_to_latex(final_state)
# Out:
# Statevector([0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j, 0.+0.j,
#              1.+0.j],
#             dims=(2, 2, 2))
# $$
#
# \begin{bmatrix}
# 0 & 0 & 0 & 0 & 0 & 0 & 0 & 1  \\
#  \end{bmatrix}
# $$

# %%
plot_bloch_multivector(final_state)

# %%
plot_state_qsphere(final_state)

# %% [markdown]
# # phase gate

# %%
import numpy as np
# Create circuit
circuit = QuantumCircuit(1)

#apply h gate
circuit.h(0)

#apply gate
# r stands for rotation and z means z axis
# circuit(phase, qbit)
circuit.rz(np.pi/4,0)

# Draw circuit
circuit.draw(output = "mpl", initial_state = True)

# %%
  # select simulator
simulator = Aer.get_backend('aer_simulator')

# save statevector
circuit.save_statevector()

#assemble circuit
qobj = assemble(circuit)

job = simulator.run(qobj)

# monitor job
job_monitor(job)

# get result
result = job.result()

# get statevector
final_state = result.get_statevector()
# Out:
# <ipython-input-77-b98e121f13c0>:10: DeprecationWarning: Using a qobj for run() is deprecated as of qiskit-aer 0.9.0 and will be removed no sooner than 3 months from that release date. Transpiled circuits should now be passed directly using `backend.run(circuits, **run_options).
#   job = simulator.run(qobj)
# Job Status: job has successfully run

# %%
print(final_state)
array_to_latex(final_state)
# Out:
# Statevector([0.65328148-0.27059805j, 0.65328148+0.27059805j],
#             dims=(2,))
# $$
#
# \begin{bmatrix}
# 0.6532814824 - 0.2705980501 i & 0.6532814824 + 0.2705980501 i  \\
#  \end{bmatrix}
# $$

# %%
plot_bloch_multivector(final_state)

# %%
plot_state_qsphere(final_state)

# %% [markdown]
# # Quantum Gate

# %%
# create circuit

circuit = QuantumCircuit(1)

# apply gate
circuit.sx(0)
circuit.sx(0)


# Circuit draw
circuit.draw(output = "mpl", initial_state=True)

# %%
  # select simulator
simulator = Aer.get_backend('aer_simulator')

# save statevector
circuit.save_statevector()

#assemble circuit
qobj = assemble(circuit)

job = simulator.run(qobj)

# monitor job
job_monitor(job)

# get result
result = job.result()

# get statevector
final_state = result.get_statevector()
# Out:
# <ipython-input-87-b98e121f13c0>:10: DeprecationWarning: Using a qobj for run() is deprecated as of qiskit-aer 0.9.0 and will be removed no sooner than 3 months from that release date. Transpiled circuits should now be passed directly using `backend.run(circuits, **run_options).
#   job = simulator.run(qobj)
# Job Status: job has successfully run

# %%
print(final_state)
array_to_latex(final_state)
# Out:
# Statevector([0.+0.j, 1.+0.j],
#             dims=(2,))
# $$
#
# \begin{bmatrix}
# 0 & 1  \\
#  \end{bmatrix}
# $$

# %%
plot_bloch_multivector(final_state)

# %%
plot_state_qsphere(final_state)
